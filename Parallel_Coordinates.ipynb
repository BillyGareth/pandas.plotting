# %%
from pandas.plotting import parallel_coordinates
import pandas as pd
import matplotlib.pyplot as plt

# %%
pc=pd.read_csv('countries.csv')

# %%
plt.figure()

# %%
parallel_coordinates(pc,'country')
