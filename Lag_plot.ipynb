# %%
from pandas.plotting import lag_plot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure()

# %%
spacing=np.linspace(-99*np.pi,99*np.pi,num=1000)

# %%
data=pd.Series(.1* np.random.rand(1000)+0.9*np.sin(spacing))

# %%
lag_plot(data)
